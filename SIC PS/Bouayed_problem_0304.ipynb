# %% [markdown]
# ## Coding Problem #0304

# %% [markdown]
# ### "Policy support rate"

# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# #### Answer the following questions by providing Python code:

# %% [markdown]
# It is known that the overall policy support rate is 52%. <br>

# %%
p = 0.52

# %% [markdown]
# 1). What is the probability of support rate less than 50% when asked to 100 people? <br>
# HINT: Use sample proportion and Standard Normal distribution.

# %%
n=100
if((n*p>10)and(n*(1-p)>10)):
  mu=p
  se=np.sqrt(p*(1-p)/n)
  z=(0.5-mu)/se
  print(st.norm.cdf(z))
# Out:
# 0.3444602779022302

# %% [markdown]
# 2). What is the probability of support rate less than 50% when asked to 300 people? <br>
# HINT: Use sample proportion and Standard Normal distribution.

# %%
n=300
if((n*p>10)and(n*(1-p)>10)):
  mu=p
  se=np.sqrt(p*(1-p)/n)
  z=(0.5-mu)/se
  print(st.norm.cdf(z))
# Out:
# 0.24403704658262387

# %% [markdown]
# 3). Redo the calculations of 1) and 2) using the Binomial distribution. Then, compare.

# %%
# Redo of 1).
n=100
X=0.5*n
st.binom.cdf(X,n,p)
# Out:
# 0.3816199474102779

# %%
# Redo of 2).
n=300
X=0.5*n
st.binom.cdf(X,n,p)
# Out:
# 0.2624050639758823

# %% [markdown]
# 4). Redo the calculations of 1) and 2) using the Poisson distribution. Then, compare.

# %% [markdown]
# >the rate of policy support can be seen as an average \begin{equation}
# \begin{aligned}
# &\lambda=52/100 \\
# \iff
# &\lambda=156/300
# \end{aligned}
# \end{equation}

# %%
# Redo of 1).
#in a sample size of 100
mu=52 
st.poisson.cdf(50,mu)
# Out:
# 0.42632224798181584

# %%
# Redo of 2).
#in a sample size of 300
mu=156
st.poisson.cdf(150,mu)
# Out:
# 0.33376351627852585
