# %% [markdown]
# ## Quiz #0402

# %% [markdown]
# ### "OLS solution"

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Answer the following question by providing Python code:
# <br>
# study = an array that contains the hours of study. This is the explanatory variable. <br>
# score = an array that contains the test scores. This is the response variable.

# %%
study = np.array([ 3, 4.5, 6, 1.2, 2, 6.9, 6.7, 5.5]).reshape(-1,1)
score = np.array([ 88, 85, 90, 80, 81, 92, 95, 90]).reshape(-1,1)

# %% [markdown]
# 1). Define the 'linerRegression' class to match the output shown below:

# %%
class linearRegression:
    def __init__(self):
      return 
        
    def train(self, input_X, input_Y):
        n = input_X.shape[0]                                      # Number of observations.
        k = input_X.shape[1]                                      # Number of explanatory variables.
        ones=np.ones((n,1))
        X=np.concatenate((ones,input_X),axis=1)
        Y=input_Y
        
        # Regression Coefficients by OLS. b=(X'X)^(-1)X'Y 
        self.beta = np.dot(np.linalg.inv(np.dot(X.T,X)),np.dot(X.T,Y))
        
        # Residuals.
        self.residuals = Y - np.dot(X,self.beta)
        
        
        # R^2.
        Y_pred=np.dot(X,self.beta)
        Y_mean=np.mean(Y)
        self.r2= np.sum(np.square(Y_pred-Y_mean))/np.sum(np.square(Y-Y_mean))     
       
        # Summary.
        self.summary=pd.DataFrame(self.beta,columns=['Coefficient'],index=['Intercept']+[f'X{i}' for i in range(1,k+1)])


        return  
    


    def output(self):
      print(self.summary)
      print("---------------------")
      print(f"R^2 : {self.r2}")

# %% [markdown]
# **Sample run:**

# %%
LR = linearRegression()                    # Create a linear regression object.
LR.train(study, score)                     # Train.
LR.output()                                # Display the training result.
# Out:
#            Coefficient
# Intercept    77.684670
# X1            2.221303
# ------------------------------
# R^2 : 0.845842

# %%
LR = linearRegression()                    # Create a linear regression object.
LR.train(study, score)                     # Train.
LR.output()
# Out:
#            Coefficient
# Intercept    77.684670
# X1            2.221303
# ---------------------
# R^2 : 0.8458423335299556
